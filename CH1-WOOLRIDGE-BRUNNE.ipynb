# %%
#WOOLRIDGE CHAPTER 1

import pandas as pd
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wage1 = pd.read_csv("wage1.csv.bz2")
wage1
# Out:
#       wage  educ  exper  tenure  nonwhite  female  married  numdep  smsa  \
# 0     3.10    11      2       0         0       1        0       2     1
# 1     3.24    12     22       2         0       1        1       3     1
# 2     3.00    11      2       0         0       0        0       2     0
# 3     6.00     8     44      28         0       0        1       0     1
# 4     5.30    12      7       2         0       0        1       1     0
# ..     ...   ...    ...     ...       ...     ...      ...     ...   ...
# 521  15.00    16     14       2         0       1        1       2     0
# 522   2.27    10      2       0         0       1        0       3     0
# 523   4.67    15     13      18         0       0        1       3     0
# 524  11.56    16      5       1         0       0        1       0     0
# 525   3.50    14      5       4         1       1        0       2     0
#
#      northcen  ...  trcommpu  trade  services  profserv  profocc  clerocc  \
# ...

# %%
wage1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      526 non-null    float64
#  1   educ      526 non-null    int64
#  2   exper     526 non-null    int64
#  3   tenure    526 non-null    int64
#  4   nonwhite  526 non-null    int64
#  5   female    526 non-null    int64
#  6   married   526 non-null    int64
#  7   numdep    526 non-null    int64
#  8   smsa      526 non-null    int64
#  9   northcen  526 non-null    int64
#  10  south     526 non-null    int64
#  11  west      526 non-null    int64
#  12  construc  526 non-null    int64
#  13  ndurman   526 non-null    int64
#  14  trcommpu  526 non-null    int64
#  15  trade     526 non-null    int64
#  16  services  526 non-null    int64
#  17  profserv  526 non-null    int64
#  18  profocc   526 non-null    int64
#  19  clerocc   526 non-null    int64
# ...

# %%
WOOLRIDGE CHAPTER 1 - THE NATURE OF ECONOMETRICS AND ECONOMIC DATA

# %% [markdown]
# C1. i. AVERAGE EDUCATION LEVEL IN THE SAMPLE

# %%
wage1['educ'].describe()
# Out:
# count    526.000000
# mean      12.562738
# std        2.769022
# min        0.000000
# 25%       12.000000
# 50%       12.000000
# 75%       14.000000
# max       18.000000
# Name: educ, dtype: float64

# %%
wage1['educ'].median()
# Out:
# 12.0

# %%
fig, ax= plt.subplots(figsize = (6,4))
ax = sns.histplot(data=wage1, x="educ", stat="frequency", color="dodgerblue", legend="False")
ax.grid(linestyle="-", linewidth="0.5", color="darkslategrey")
ax.set_title("AVERAGE EDUCATION LEVEL")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, '')

# %%
ii. AVERAGE HOURLY WAGE - SEEMS LOW!

# %%
wage1['wage'].describe()
# Out:
# count    526.000000
# mean       5.896103
# std        3.693086
# min        0.530000
# 25%        3.330000
# 50%        4.650000
# 75%        6.880000
# max       24.980000
# Name: wage, dtype: float64

# %%
wage1['wage'].median()
# Out:
# 4.650000095367432

# %%
fig2, ax2= plt.subplots(figsize = (6,4))
ax = sns.histplot(data=wage1, x="wage", stat="frequency", color="dodgerblue", legend="False")
ax.grid(linestyle="-", linewidth="0.5", color="darkslategrey")
ax.set_title("AVERAGE HOURLY WAGE")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, '')

# %%
iii.

# %%
iv. Use the CPI (CONSUMER PRICE INDEX) from part iii. to find the average hourly wage in 2010 in dollars. 
    Now does the average hourly wage seem reasonable?

# %%
v.  How many women are in the BWGHT.RAW sample?

# %%
bwght = pd.read_csv("bwght.csv.bz2")
bwght.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   faminc    1388 non-null   float64
#  1   cigtax    1388 non-null   float64
#  2   cigprice  1388 non-null   float64
#  3   bwght     1388 non-null   int64
#  4   fatheduc  1192 non-null   float64
#  5   motheduc  1387 non-null   float64
#  6   parity    1388 non-null   int64
#  7   male      1388 non-null   int64
#  8   white     1388 non-null   int64
#  9   cigs      1388 non-null   int64
#  10  lbwght    1388 non-null   float64
#  11  bwghtlbs  1388 non-null   float64
#  12  packs     1388 non-null   float64
#  13  lfaminc   1388 non-null   float64
# dtypes: float64(9), int64(5)
# memory usage: 151.9 KB

# %%
bwght.describe()
# Out:
#             faminc       cigtax     cigprice        bwght     fatheduc  \
# count  1388.000000  1388.000000  1388.000000  1388.000000  1192.000000
# mean     29.026657    19.552954   130.559006   118.699568    13.186242
# std      18.739285     7.795598    10.244485    20.353964     2.745985
# min       0.500000     2.000000   103.800003    23.000000     1.000000
# 25%      14.500000    15.000000   122.800003   107.000000    12.000000
# 50%      27.500000    20.000000   130.800003   120.000000    12.000000
# 75%      37.500000    26.000000   137.000000   132.000000    16.000000
# max      65.000000    38.000000   152.500000   271.000000    18.000000
#
#           motheduc       parity         male        white         cigs  \
# count  1387.000000  1388.000000  1388.000000  1388.000000  1388.000000
# mean     12.935833     1.632565     0.520893     0.784582     2.087176
# std       2.376728     0.894027     0.499743     0.411260     5.972688
# ...

# %%
1388 - (bwght['male'].sum())
# Out:
# 665

# %%
i. HOW MANY OF THE WOMEN REPORT SMOKING DURING PREGNANCY?
# Out:
# Object `PREGNANCY` not found.

# %%
women = bwght['male'] == 0

# %%
women
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1383    False
# 1384    False
# 1385     True
# 1386     True
# 1387     True
# Name: male, Length: 1388, dtype: bool

# %%
ii. What is the average number of cigarettes smoked per day?

# %%
women_filt = (bwght['male'] == 0)
bwght[women_filt]
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 2        0.5    16.5  122.300003    129       NaN      12.0       2     0
# 6       65.0    16.5  122.300003    140      16.0      14.0       2     0
# 7       27.5    16.5  122.300003     86      12.0      14.0       2     0
# 8       27.5    16.5  122.300003    121      12.0      17.0       2     0
# 9       37.5    16.5  122.300003    129      16.0      18.0       2     0
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1379     1.5    30.0  138.300003    130      10.0      11.0       3     0
# 1382    22.5    30.0  138.300003    135      16.0      16.0       3     0
# 1385    65.0     8.0  118.599998    135      18.0      16.0       2     0
# 1386    27.5     8.0  118.599998    118       NaN      14.0       2     0
# 1387    37.5     8.0  118.599998    111      16.0      13.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %%
bwght[women_filt]['cigs'].describe()
# Out:
# count    665.000000
# mean       2.090226
# std        5.659594
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       40.000000
# Name: cigs, dtype: float64

# %%
bwght[women_filt]['cigs'].median()
# Out:
# 0.0

# %%
fig, ax= plt.subplots(figsize = (6,4))
ax = sns.histplot(data=bwght[women_filt], x="cigs", stat="frequency", color="dodgerblue", legend="False")
ax.grid(linestyle="-", linewidth="0.5", color="darkslategrey")
ax.set_title("AVERAGE CIGS SMOKED BY WOMEN")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, '')

# %%
iv. Find the average of fatheduc in the sample. Why are there only 1,192 observations used to compute this average?

# %%
bwght['fatheduc'].describe()
# Out:
# count    1192.000000
# mean       13.186242
# std         2.745985
# min         1.000000
# 25%        12.000000
# 50%        12.000000
# 75%        16.000000
# max        18.000000
# Name: fatheduc, dtype: float64

# %%
(bwght['fatheduc'] == 0).sum()
# Out:
# 0

# %%
bwght['fatheduc'].isnull().sum()
# Out:
# 196

# %%
1388-196
# Out:
# 1192

# %%
bwght.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   faminc    1388 non-null   float64
#  1   cigtax    1388 non-null   float64
#  2   cigprice  1388 non-null   float64
#  3   bwght     1388 non-null   int64
#  4   fatheduc  1192 non-null   float64
#  5   motheduc  1387 non-null   float64
#  6   parity    1388 non-null   int64
#  7   male      1388 non-null   int64
#  8   white     1388 non-null   int64
#  9   cigs      1388 non-null   int64
#  10  lbwght    1388 non-null   float64
#  11  bwghtlbs  1388 non-null   float64
#  12  packs     1388 non-null   float64
#  13  lfaminc   1388 non-null   float64
# dtypes: float64(9), int64(5)
# memory usage: 151.9 KB

# %%
bwght['faminc'].describe()
# Out:
# count    1388.000000
# mean       29.026657
# std        18.739285
# min         0.500000
# 25%        14.500000
# 50%        27.500000
# 75%        37.500000
# max        65.000000
# Name: faminc, dtype: float64

# %%
fig4, ax4= plt.subplots(figsize = (6,4))
ax = sns.histplot(data=bwght, x="faminc", stat="frequency", color="dodgerblue", legend="False")
ax.grid(linestyle="-", linewidth="0.5", color="darkslategrey")
ax.set_title("AVERAGE FAMILY INCOME")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, '')

# %%
bwght['faminc'].median()
# Out:
# 27.5

# %%
C3.

# %%
meap01 = pd.read_csv("meap01.csv.bz2")
meap01
# Out:
#         dcode  bcode      math4      read4      lunch  enroll     expend  \
# 0      1010.0   4937  83.300003  77.800003  40.599998     468  2747475.0
# 1      2070.0    597  90.300003  82.300003  27.100000     679  1505772.0
# 2      2080.0   4860  61.900002  71.400002  41.750000     400  2121871.0
# 3      3010.0    790  85.699997  60.000000  12.750000     251  1211034.0
# 4      3010.0   1403  77.300003  59.099998  17.080000     439  1913501.0
# ...       ...    ...        ...        ...        ...     ...        ...
# 1818  83010.0   2024  93.599998  57.400002  50.529999     285  1484497.0
# 1819  83010.0   2210  69.000000  48.799999  53.670002     259  1279763.0
# 1820  83010.0   2480  72.500000  63.400002  46.849998     254  1241369.0
# 1821  83010.0   5101  81.000000  73.800003  34.299999     277  1312697.0
# 1822  83070.0   2527  88.099998  56.700001  52.920002     650  1660206.0
#
#             exppp   lenroll    lexpend    lexppp
# ...

# %%
C4

# %%
jtrain2 = pd.read_csv("jtrain2.csv.bz2")
jtrain2
# Out:
#      train  age  educ  black  hisp  married  nodegree  mosinex       re74  \
# 0        1   37    11      1     0        1         1       13   0.000000
# 1        1   22     9      0     1        0         1       13   0.000000
# 2        1   30    12      1     0        0         0       13   0.000000
# 3        1   27    11      1     0        0         1       13   0.000000
# 4        1   33     8      1     0        0         1       13   0.000000
# ..     ...  ...   ...    ...   ...      ...       ...      ...        ...
# 440      0   21     9      1     0        0         1       23  31.886402
# 441      0   28    11      1     0        0         1       24  17.491499
# 442      0   29     9      0     1        0         1       23   9.594309
# 443      0   25     9      1     0        1         1       22  24.731600
# 444      0   22    10      0     0        1         1       22  25.720901
#
#           re75       re78  unem74  unem75  unem78     lre74     lre75  \
# ...

# %%
fertil2 = pd.read_csv("fertil2.csv.bz2")
fertil2
# Out:
#       mnthborn  yearborn  age  electric  radio   tv  bicycle  educ  ceb  \
# 0            5        64   24       1.0    1.0  1.0      1.0    12    0
# 1            1        56   32       1.0    1.0  1.0      1.0    13    3
# 2            7        58   30       1.0    0.0  0.0      0.0     5    1
# 3           11        45   42       1.0    0.0  1.0      0.0     4    3
# 4            5        45   43       1.0    1.0  1.0      1.0    11    2
# ...        ...       ...  ...       ...    ...  ...      ...   ...  ...
# 4356         6        72   16       0.0    1.0  0.0      0.0     7    0
# 4357         1        60   28       0.0    1.0  0.0      0.0     7    2
# 4358        11        63   24       0.0    1.0  0.0      0.0     5    4
# 4359         1        62   26       0.0    1.0  0.0      0.0     0    1
# 4360        12        51   36       0.0    1.0  0.0      0.0     3    6
#
#       agefbrth  ...  heduc  agesq  urban  urb_educ  spirit  protest  catholic  \
# ...

# %%
pd.crosstab(index=bwght['male'], columns=bwght['packs'], normalize="columns")

# %%
#CHAPTER 1 - HEISS & BRUNNER

# %%
p=1
if p <= 0.05:
    print("reject H0!")
else:
    print("don't reject H0!")
# Out:
# don't reject H0!

# %%
seq = [1,2,3,4,5,6]
for i in seq:
    if i < 4:
        print(i ** 3)
    else:
        print(i ** 2)
# Out:
# 1
# 8
# 27
# 16
# 25
# 36

# %%
seq = [1,2,3,4,5,6]
for i in range(len(seq)):
    if seq[i] < 4:
        print(seq[i] **3)
    else:
        print(seq[i] **2)
# Out:
# 1
# 8
# 27
# 16
# 25
# 36

# %%
errors = pd.read_excel("errors.xlsx")
errors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1673c5b470ca> in <module>
# ----> 1 errors = pd.read_excel("errors.xlsx")
#       2 errors
#
# NameError: name 'pd' is not defined

# %%
dt = errors.machineID
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9dc856234b00> in <module>
# ----> 1 dt = errors.machineID
#       2 dt
#
# NameError: name 'errors' is not defined

# %%
for i in range(len(dt)):
    if dt[i] < 50:
        print('finishing machine')
    else:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fb2640c19b34> in <module>
# ----> 1 for i in range(len(dt)):
#       2     if dt[i] < 50:
#       3         print('finishing machine')
#       4     else:
#       5         print(i)
#
# NameError: name 'dt' is not defined

# %%
# PAGE 62
def mysqrt(x):
    if x >= 0:
        result = x ** 0.5
    else:
        result = "You Fool!"
    return result

# %%
mysqrt(4)
# Out:
# 2.0

# %%
4**0.5
# Out:
# 2.0

# %%
result1 = mysqrt(4)
print(f'result1: {result1}\n')
# Out:
# result1: 2.0

# %%
result2 = mysqrt(-1.5)
print(f'result2: {result2}\n')
# Out:
# result2: You Fool!

# %%
#CLASSES -MANY THAT WE USE ARE PREDIFINED (LIKE LIST)
a = [2,6,3,6]

# %%
type(a).__name__
# Out:
# 'list'

# %%
type(a)
# Out:
# list

# %%
a.count(6)
# Out:
# 2

# %%
a.sort()

# %%
a
# Out:
# [2, 3, 6, 6]

# %%
import pandas as pd 
import numpy as np

# %%
#MAKE OUR OWN CLASS - LOCAL VARIABLES ARE ALWAYS INITIATED BY THE __init__ method in Python
c = np.array([[3,6,1], [2,7,4]])
d = np.array([[1,8,6], [3,5,8], [1,1,2]])

# %%
c
# Out:
# array([[3, 6, 1],
#        [2, 7, 4]])

# %%
d
# Out:
# array([[1, 8, 6],
#        [3, 5, 8],
#        [1, 1, 2]])

# %%
#NUMPY WAY TO MULTIPLY MATRICES
c.dot(d)
# Out:
# array([[22, 55, 68],
#        [27, 55, 76]])

# %%
class myMatrices:
    def __init__(self, C, D):
        self.C = C
        self.D = D
    
    def mult(self):
        N = self.C.shape[0] #number of rows in C
        K = self.D.shape[1] #number of cols in D
        out = np.empty((N,K)) # initialize output
        for i in range(N):
            for j in range(K):
                out[i,j] = sum(self.C[i, :] * self.D[:,j])
        return out

# %%
# create object    
test = myMatrices(c, d)

# %%
# access local variables
test.C
# Out:
# array([[3, 6, 1],
#        [2, 7, 4]])

# %%
test.D
# Out:
# array([[1, 8, 6],
#        [3, 5, 8],
#        [1, 1, 2]])

# %%
test.mult()
# Out:
# array([[22., 55., 68.],
#        [27., 55., 76.]])

# %%
class myMatNew(myMatrices):
    def getTotalElem(self):
        N = self.C.shape[0] # num of rows in C
        K = self.D.shape[1] # num of rows in D
        return N * K

# %%
testsb = myMatNew(c,d)

# %%
testsb.getTotalElem()
# Out:
# 6

# %%
myMatNew(c,d).getTotalElem()
# Out:
# 6

# %%
import scipy.stats as stats

# %%
np.random.seed(123456)

# %%
n=100

# %%
n
# Out:
# 100

# %%
sample1 = stats.norm.rvs(10,2, size=n)

# %%
sample1
# Out:
# array([10.9382246 ,  9.43427331,  6.98188299,  7.72873526, 12.42422405,
#         9.6535707 , 10.23841742,  7.91152807,  8.27630207,  5.79086156,
#         9.01014145, 12.14360761, 11.44311032,  8.58645773,  7.92085003,
#        10.54371977,  9.15005534, 11.1340407 , 10.55246404,  7.82519862,
#         8.65262058, 10.22729682,  7.0431469 , 11.04997533, 10.80941044,
#        11.15409197,  6.56999597,  7.92146303,  9.25870628,  7.6842155 ,
#         7.31137637, 11.68977028, 12.15153957,  9.78190005, 13.28712614,
#         7.06122408, 10.71404113,  8.65079979,  6.44619257,  8.06217238,
#         7.41095282, 10.82747621, 10.55332343,  9.05593098,  9.9720805 ,
#         9.27491402,  9.98769286,  8.15387869, 11.7914346 , 11.61048805,
#         7.58717644, 15.13129189, 12.86251197, 12.6806177 ,  7.65940241,
#         9.54766143, 10.82166902, 11.62770057, 10.26400634,  8.34536613,
#         9.84706596,  7.62464485, 12.2602546 ,  7.12652536,  7.17263826,
# ...

# %%
estimate1 = np.mean(sample1)

# %%
estimate1
# Out:
# 9.573602656614304

# %%
sample2 = stats.norm.rvs(10,2,size=n)
sample3 = stats.norm.rvs(10,2,size=n)
estimate2 = np.mean(sample2)
estimate3 = np.mean(sample3)

# %%
estimate2
# Out:
# 10.24798129790092

# %%
estimate3
# Out:
# 9.96021755398913

# %%
r = 10000
ybar = np.empty(r)

# %%
for j in range(r):
    sample = stats.norm.rvs(10,2,size=n)
    ybar[j] = np.mean(sample)

# %%
ybar
# Out:
# array([ 9.67635967,  9.82261605,  9.6270579 , ...,  9.99419925,
#        10.109608  ,  9.78271154])

# %%
len(ybar)
# Out:
# 10000

# %%
np.var(ybar, ddof=1)
# Out:
# 0.039878086687435275

# %%
np.mean(ybar)
# Out:
# 10.00083465240343

# %%
#ASYMPTOTIC PROPERTIES OF ESTIMATORS
#CENTRAL LIMIT THEREOM ----> AS n approaches infinity, the sample mean of a random sample will eventually always be 
# normally distributed, no matter what the distribution of Y is (unless it is very weird with infinite variance)

# %%
sample5 = stats.chi2.rvs(1, size=n)

# %%
for j in range(r):
    sample = stats.norm.rvs(10,2,size=n)
    ybar[j] = np.mean(sample)
